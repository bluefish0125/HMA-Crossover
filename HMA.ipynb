# %%
# Lets Import all our packages nesscary for data importing
import datetime
import os
import shutil
from decimal import Decimal

import fsspec
import pandas as pd
from nautilus_trader.core.datetime import dt_to_unix_nanos
from nautilus_trader.model.data import QuoteTick
from nautilus_trader.model.objects import Price, Quantity

from nautilus_trader.backtest.node import BacktestNode, BacktestVenueConfig, BacktestDataConfig, BacktestRunConfig, BacktestEngineConfig
from nautilus_trader.config import ImportableStrategyConfig
from nautilus_trader.config import LoggingConfig
from nautilus_trader.persistence.catalog import ParquetDataCatalog
from nautilus_trader.test_kit.providers import TestInstrumentProvider

# %%
from nautilus_trader.persistence.catalog import ParquetDataCatalog
catalog = ParquetDataCatalog.from_env()
catalog.instruments()
# Out:
# [CurrencyPair(id=EUR/USD.SIM, raw_symbol=EUR/USD, asset_class=FX, asset_type=SPOT, quote_currency=USD, is_inverse=False, price_precision=5, price_increment=0.00001, size_precision=0, size_increment=1, multiplier=1, lot_size=1000, margin_init=0.03, margin_maint=0.03, maker_fee=0.00002, taker_fee=0.00002, info=None)]

# %% [markdown]
# ### Writing a HMA Trading Strategy

# %%
from typing import Optional
from nautilus_trader.core.message import Event
from nautilus_trader.indicators.average.hma import HullMovingAverage
from nautilus_trader.model.data import QuoteTick
from nautilus_trader.model.enums import PriceType
from nautilus_trader.model.enums import PositionSide
from nautilus_trader.model.enums import OrderSide
from nautilus_trader.model.events import PositionOpened
from nautilus_trader.model.identifiers import InstrumentId
from nautilus_trader.model.objects import Quantity
from nautilus_trader.model.position import Position
from nautilus_trader.trading.strategy import Strategy, StrategyConfig

# %%
class HMAConfig(StrategyConfig):
    instrument_id: str
    period: int = 16
    price_type: PriceType = PriceType.MID
    trade_size: int = 1_000

class HMAStrategy(Strategy):
    def __init__(self, config: HMAConfig):
        super().__init__(config=config)
        # Our "trading signal"
        self.hma = HullMovingAverage(period = config.period,
        price_type= config.price_type)
        self.instrument_id = InstrumentId.from_str(config.instrument_id)
        self.trade_size = Quantity.from_int(config.trade_size)

    # Convenience
        self.position: Optional[Position] = None
    # On start
    def on_start(self):
        # subscribe to data  
        self.subscribe_quote_ticks(instrument_id=self.instrument_id)

    # On end
    def on_stop(self):
        # Close all positions
        self.close_all_positions(self.instrument_id)
        # stop subscribing to data
        self.unsubscribe_quote_ticks(instrument_id=self.instrument_id)

    def on_quote_tick(self, tick:QuoteTick):
        # Updates indicator with quote tick 
        self.hma.handle_quote_tick(tick)
        self.bid = tick.bid_price
        if not self.hma.initialized:
            return # wait for indicator to start

        self.check_for_entry()
        self.check_for_exit()

    def on_event(self, event: Event):
        if isinstance(event, PositionOpened):
            self.position = self.cache.position(event.position_id)

    def check_for_entry(self):
        # if the current bid is above the hma, we go long
        if self.bid > self.hma.value:
            if self.position and self.position.side == PositionSide.LONG:
                return # already LONG

            order = self.order_factory.market(
                instrument_id = self.instrument_id,
                order_side = OrderSide.BUY,
                quantity = self.trade_size
            )
            self.submit_order(order)
        # if the current bid is below the hma, we go short
        elif self.bid < self.hma.value:
            if self.position and self.position.side == PositionSide.SHORT:
                return # already SHORT

            order = self.order_factory.market(
                instrument_id = self.instrument_id,
                order_side = OrderSide.SELL,
                quantity = self.trade_size
            )
            self.submit_order(order)

    def check_for_exit(self):
        if self.bid >= self.hma.value:
            if self.position and self.position.side == PositionSide.SHORT:
                self.close_position(self.position)
            # If the bid is greater than hma line, close all SHORT positions

        else:
            if self.position and self.position.side == PositionSide.LONG:
                self.close_position(self.position)


    def on_dispose(self):
        pass # do nothing

# %%
# Backtest Config
from nautilus_trader.config import BacktestVenueConfig

venue = BacktestVenueConfig(
    name='SIM',
    oms_type='NETTING',
    account_type="MARGIN",
    base_currency='USD',
    starting_balances=['1_000_000 USD']
)

# %%
instruments = catalog.instruments(as_nautilus=True)
instruments
# Out:
# [CurrencyPair(id=EUR/USD.SIM, raw_symbol=EUR/USD, asset_class=FX, asset_type=SPOT, quote_currency=USD, is_inverse=False, price_precision=5, price_increment=0.00001, size_precision=0, size_increment=1, multiplier=1, lot_size=1000, margin_init=0.03, margin_maint=0.03, maker_fee=0.00002, taker_fee=0.00002, info=None)]

# %%
from nautilus_trader.config import BacktestDataConfig
from nautilus_trader.model.data import QuoteTick

data = BacktestDataConfig(
    catalog_path=(catalog.path),
    data_cls=QuoteTick,
    instrument_id=str(instruments[0].id),
    end_time='2020-01-10',
)

# %%
from nautilus_trader.config import BacktestEngineConfig
from nautilus_trader.config import ImportableStrategyConfig

engine = BacktestEngineConfig(
    strategies=[
        ImportableStrategyConfig(
            strategy_path='__main__:HMAStrategy',
            config_path='__main__:HMAConfig',
            config=dict(
                instrument_id=instruments[0].id.value,
                period=16,
                ),
        )
    ],
    logging=LoggingConfig(log_level='ERROR'),
)

# %%
from nautilus_trader.config import BacktestRunConfig

config = BacktestRunConfig(
    engine=engine,
    data=[data],
    venues=[venue],
)

# %%
from nautilus_trader.backtest.node import BacktestNode
from nautilus_trader.backtest.results import BacktestResult

node = BacktestNode(configs=[config])

results: list[BacktestResult] = node.run()
# Out:
# thread '<unnamed>' panicked at common/src/msgbus.rs:403:48:
# called `Result::unwrap()` on an `Err` value: Connection refused (os error 111)
# note: run with `RUST_BACKTRACE=1` environment variable to display a backtrace

# %%
from nautilus_trader.backtest.engine import BacktestEngine
from nautilus_trader.model.identifiers import Venue

engine: BacktestEngine = node.get_engine(config.id)

engine.trader.generate_order_fills_report()
# Out:
#                                      trader_id      strategy_id instrument_id  \
# client_order_id
# O-20200101-1701-001-000-1       BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200101-1717-001-000-2       BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200101-1717-001-000-4       BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200101-1717-001-000-5       BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200101-1717-001-000-7       BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# ...                                        ...              ...           ...
# O-20200109-2359-001-000-175652  BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200109-2359-001-000-175654  BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200109-2359-001-000-175655  BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200109-2359-001-000-175657  BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
# O-20200109-2359-001-000-175658  BACKTESTER-001  HMAStrategy-000   EUR/USD.SIM
#
#                                venue_order_id                  position_id  \
# client_order_id
# O-20200101-1701-001-000-1           SIM-1-001  EUR/USD.SIM-HMAStrategy-000
# O-20200101-1717-001-000-2           SIM-1-002  EUR/USD.SIM-HMAStrategy-000
# O-20200101-1717-001-000-4           SIM-1-003  EUR/USD.SIM-HMAStrategy-000
# O-20200101-1717-001-000-5           SIM-1-004  EUR/USD.SIM-HMAStrategy-000
# O-20200101-1717-001-000-7           SIM-1-005  EUR/USD.SIM-HMAStrategy-000
# ...                                       ...                          ...
# O-20200109-2359-001-000-175652   SIM-1-117102  EUR/USD.SIM-HMAStrategy-000
# O-20200109-2359-001-000-175654   SIM-1-117103  EUR/USD.SIM-HMAStrategy-000
# O-20200109-2359-001-000-175655   SIM-1-117104  EUR/USD.SIM-HMAStrategy-000
# O-20200109-2359-001-000-175657   SIM-1-117105  EUR/USD.SIM-HMAStrategy-000
# O-20200109-2359-001-000-175658   SIM-1-117106  EUR/USD.SIM-HMAStrategy-000
#
#                                account_id last_trade_id    type  side  \
# client_order_id
# O-20200101-1701-001-000-1         SIM-001     SIM-1-001  MARKET  SELL
# O-20200101-1717-001-000-2         SIM-001     SIM-1-002  MARKET   BUY
# O-20200101-1717-001-000-4         SIM-001     SIM-1-003  MARKET   BUY
# O-20200101-1717-001-000-5         SIM-001     SIM-1-004  MARKET  SELL
# O-20200101-1717-001-000-7         SIM-001     SIM-1-005  MARKET  SELL
# ...                                   ...           ...     ...   ...
# O-20200109-2359-001-000-175652    SIM-001  SIM-1-117102  MARKET   BUY
# O-20200109-2359-001-000-175654    SIM-001  SIM-1-117103  MARKET   BUY
# O-20200109-2359-001-000-175655    SIM-001  SIM-1-117104  MARKET  SELL
# O-20200109-2359-001-000-175657    SIM-001  SIM-1-117105  MARKET  SELL
# O-20200109-2359-001-000-175658    SIM-001  SIM-1-117106  MARKET   BUY
#
#                                quantity  ... contingency_type  order_list_id  \
# client_order_id                          ...
# O-20200101-1701-001-000-1          1000  ...   NO_CONTINGENCY           None
# O-20200101-1717-001-000-2          1000  ...   NO_CONTINGENCY           None
# O-20200101-1717-001-000-4          1000  ...   NO_CONTINGENCY           None
# O-20200101-1717-001-000-5          1000  ...   NO_CONTINGENCY           None
# O-20200101-1717-001-000-7          1000  ...   NO_CONTINGENCY           None
# ...                                 ...  ...              ...            ...
# O-20200109-2359-001-000-175652     1000  ...   NO_CONTINGENCY           None
# O-20200109-2359-001-000-175654     1000  ...   NO_CONTINGENCY           None
# O-20200109-2359-001-000-175655     1000  ...   NO_CONTINGENCY           None
# O-20200109-2359-001-000-175657     1000  ...   NO_CONTINGENCY           None
# O-20200109-2359-001-000-175658     1000  ...   NO_CONTINGENCY           None
#
#                                 linked_order_ids parent_order_id  \
# client_order_id
# O-20200101-1701-001-000-1                   None            None
# O-20200101-1717-001-000-2                   None            None
# O-20200101-1717-001-000-4                   None            None
# O-20200101-1717-001-000-5                   None            None
# O-20200101-1717-001-000-7                   None            None
# ...                                          ...             ...
# O-20200109-2359-001-000-175652              None            None
# O-20200109-2359-001-000-175654              None            None
# O-20200109-2359-001-000-175655              None            None
# O-20200109-2359-001-000-175657              None            None
# O-20200109-2359-001-000-175658              None            None
#
#                                exec_algorithm_id exec_algorithm_params  \
# client_order_id
# O-20200101-1701-001-000-1                   None                  None
# O-20200101-1717-001-000-2                   None                  None
# O-20200101-1717-001-000-4                   None                  None
# O-20200101-1717-001-000-5                   None                  None
# O-20200101-1717-001-000-7                   None                  None
# ...                                          ...                   ...
# O-20200109-2359-001-000-175652              None                  None
# O-20200109-2359-001-000-175654              None                  None
# O-20200109-2359-001-000-175655              None                  None
# O-20200109-2359-001-000-175657              None                  None
# O-20200109-2359-001-000-175658              None                  None
#
#                                exec_spawn_id  tags  \
# client_order_id
# O-20200101-1701-001-000-1               None  None
# O-20200101-1717-001-000-2               None  None
# O-20200101-1717-001-000-4               None  None
# O-20200101-1717-001-000-5               None  None
# O-20200101-1717-001-000-7               None  None
# ...                                      ...   ...
# O-20200109-2359-001-000-175652          None  None
# O-20200109-2359-001-000-175654          None  None
# O-20200109-2359-001-000-175655          None  None
# O-20200109-2359-001-000-175657          None  None
# O-20200109-2359-001-000-175658          None  None
#
#                                                         ts_init  \
# client_order_id
# O-20200101-1701-001-000-1      2020-01-01 17:01:21.324000+00:00
# O-20200101-1717-001-000-2      2020-01-01 17:17:29.270000+00:00
# O-20200101-1717-001-000-4      2020-01-01 17:17:29.321000+00:00
# O-20200101-1717-001-000-5      2020-01-01 17:17:29.372000+00:00
# O-20200101-1717-001-000-7      2020-01-01 17:17:29.473000+00:00
# ...                                                         ...
# O-20200109-2359-001-000-175652 2020-01-09 23:59:01.433000+00:00
# O-20200109-2359-001-000-175654 2020-01-09 23:59:41.940000+00:00
# O-20200109-2359-001-000-175655 2020-01-09 23:59:42.322000+00:00
# O-20200109-2359-001-000-175657 2020-01-09 23:59:54.079000+00:00
# O-20200109-2359-001-000-175658 2020-01-09 23:59:59.448000+00:00
#
#                                                         ts_last
# client_order_id
# O-20200101-1701-001-000-1      2020-01-01 17:01:21.324000+00:00
# O-20200101-1717-001-000-2      2020-01-01 17:17:29.270000+00:00
# O-20200101-1717-001-000-4      2020-01-01 17:17:29.321000+00:00
# O-20200101-1717-001-000-5      2020-01-01 17:17:29.372000+00:00
# O-20200101-1717-001-000-7      2020-01-01 17:17:29.473000+00:00
# ...                                                         ...
# O-20200109-2359-001-000-175652 2020-01-09 23:59:01.433000+00:00
# O-20200109-2359-001-000-175654 2020-01-09 23:59:41.940000+00:00
# O-20200109-2359-001-000-175655 2020-01-09 23:59:42.322000+00:00
# O-20200109-2359-001-000-175657 2020-01-09 23:59:54.079000+00:00
# O-20200109-2359-001-000-175658 2020-01-09 23:59:59.448000+00:00
#
# [117106 rows x 29 columns]

# %%
engine.trader.generate_positions_report()
# Out:
#                                                          trader_id  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...  BACKTESTER-001
# ...                                                            ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...  BACKTESTER-001
# EUR/USD.SIM-HMAStrategy-000                         BACKTESTER-001
#
#                                                         strategy_id  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...  HMAStrategy-000
# ...                                                             ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...  HMAStrategy-000
# EUR/USD.SIM-HMAStrategy-000                         HMAStrategy-000
#
#                                                    instrument_id account_id  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...   EUR/USD.SIM    SIM-001
# ...                                                          ...        ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...   EUR/USD.SIM    SIM-001
# EUR/USD.SIM-HMAStrategy-000                          EUR/USD.SIM    SIM-001
#
#                                                                   opening_order_id  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...       O-20200101-1701-001-000-1
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...       O-20200101-1717-001-000-4
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...       O-20200101-1717-001-000-7
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...      O-20200101-1719-001-000-10
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...      O-20200101-1719-001-000-13
# ...                                                                            ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...  O-20200109-2348-001-000-175645
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...  O-20200109-2354-001-000-175648
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...  O-20200109-2354-001-000-175651
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...  O-20200109-2359-001-000-175654
# EUR/USD.SIM-HMAStrategy-000                         O-20200109-2359-001-000-175657
#
#                                                                   closing_order_id  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...       O-20200101-1717-001-000-2
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...       O-20200101-1717-001-000-5
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...       O-20200101-1719-001-000-8
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...      O-20200101-1719-001-000-11
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...      O-20200101-1719-001-000-14
# ...                                                                            ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...  O-20200109-2354-001-000-175646
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...  O-20200109-2354-001-000-175649
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...  O-20200109-2359-001-000-175652
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...  O-20200109-2359-001-000-175655
# EUR/USD.SIM-HMAStrategy-000                         O-20200109-2359-001-000-175658
#
#                                                    entry  side peak_qty  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...  SELL  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...   BUY  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...  SELL  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...  SELL  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...   BUY  FLAT     1000
# ...                                                  ...   ...      ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...  SELL  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...   BUY  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...  SELL  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...   BUY  FLAT     1000
# EUR/USD.SIM-HMAStrategy-000                         SELL  FLAT     1000
#
#                                                                           ts_opened  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-... 2020-01-01 17:01:21.324000+00:00
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-... 2020-01-01 17:17:29.321000+00:00
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-... 2020-01-01 17:17:29.473000+00:00
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-... 2020-01-01 17:19:12.822000+00:00
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-... 2020-01-01 17:19:23.566000+00:00
# ...                                                                             ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-... 2020-01-09 23:48:24.146000+00:00
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-... 2020-01-09 23:54:41.678000+00:00
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-... 2020-01-09 23:54:42.083000+00:00
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-... 2020-01-09 23:59:41.940000+00:00
# EUR/USD.SIM-HMAStrategy-000                        2020-01-09 23:59:54.079000+00:00
#
#                                                                 ts_last  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...  1577899049270000000
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...  1577899049372000000
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...  1577899152771000000
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...  1577899163464000000
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...  1577899177961000000
# ...                                                                 ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...  1578614081566000000
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...  1578614081931000000
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...  1578614341433000000
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...  1578614382322000000
# EUR/USD.SIM-HMAStrategy-000                         1578614399448000000
#
#                                                                           ts_closed  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-... 2020-01-01 17:17:29.270000+00:00
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-... 2020-01-01 17:17:29.372000+00:00
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-... 2020-01-01 17:19:12.771000+00:00
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-... 2020-01-01 17:19:23.464000+00:00
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-... 2020-01-01 17:19:37.961000+00:00
# ...                                                                             ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-... 2020-01-09 23:54:41.566000+00:00
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-... 2020-01-09 23:54:41.931000+00:00
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-... 2020-01-09 23:59:01.433000+00:00
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-... 2020-01-09 23:59:42.322000+00:00
# EUR/USD.SIM-HMAStrategy-000                        2020-01-09 23:59:59.448000+00:00
#
#                                                      duration_ns avg_px_open  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...  967946000000     1.12126
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...      51000000     1.12166
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...  103298000000     1.12143
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...   10642000000     1.12135
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...   14395000000     1.12151
# ...                                                          ...         ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...  377420000000      1.1107
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...     253000000     1.11078
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...  259350000000     1.11074
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...     382000000     1.11078
# EUR/USD.SIM-HMAStrategy-000                           5369000000     1.11075
#
#                                                    avg_px_close   commissions  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...       1.1216  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...      1.12144  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...      1.12145  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...      1.12151  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...      1.12146  ['0.04 USD']
# ...                                                         ...           ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...      1.11075  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...      1.11074  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...      1.11077  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...      1.11074  ['0.04 USD']
# EUR/USD.SIM-HMAStrategy-000                             1.11078  ['0.04 USD']
#
#                                                    realized_return  \
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...         -0.0003
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...         -0.0002
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...          -2e-05
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...        -0.00014
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...          -4e-05
# ...                                                            ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...          -5e-05
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...          -4e-05
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...          -3e-05
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...          -4e-05
# EUR/USD.SIM-HMAStrategy-000                                 -3e-05
#
#                                                    realized_pnl
# position_id
# EUR/USD.SIM-HMAStrategy-000-23f8d283-d6c5-48b3-...    -0.38 USD
# EUR/USD.SIM-HMAStrategy-000-568c09bd-716b-4e9a-...    -0.26 USD
# EUR/USD.SIM-HMAStrategy-000-f182775e-b0d6-490c-...    -0.06 USD
# EUR/USD.SIM-HMAStrategy-000-f5d5d64a-edbd-4619-...    -0.20 USD
# EUR/USD.SIM-HMAStrategy-000-bf39d274-b5c1-46d8-...    -0.09 USD
# ...                                                         ...
# EUR/USD.SIM-HMAStrategy-000-762c0bfc-45e6-4508-...    -0.09 USD
# EUR/USD.SIM-HMAStrategy-000-20755b09-acd6-49be-...    -0.08 USD
# EUR/USD.SIM-HMAStrategy-000-f8623f6d-d4e4-4157-...    -0.07 USD
# EUR/USD.SIM-HMAStrategy-000-f24b7b2e-ccf8-4f4e-...    -0.08 USD
# EUR/USD.SIM-HMAStrategy-000                           -0.07 USD
#
# [58553 rows x 18 columns]

# %%
engine.trader.generate_account_report(Venue('SIM'))
# Out:
#                                        total locked        free currency  \
# 2020-01-01 17:00:10.447000+00:00  1000000.00   0.00  1000000.00      USD
# 2020-01-01 17:01:21.324000+00:00   999999.98   0.00   999999.98      USD
# 2020-01-01 17:01:21.324000+00:00   999999.98  33.66   999966.32      USD
# 2020-01-01 17:17:29.270000+00:00   999999.62  33.66   999965.96      USD
# 2020-01-01 17:17:29.270000+00:00   999999.62   0.00   999999.62      USD
# ...                                      ...    ...         ...      ...
# 2020-01-09 23:59:42.322000+00:00   996680.71   0.00   996680.71      USD
# 2020-01-09 23:59:54.079000+00:00   996680.69   0.00   996680.69      USD
# 2020-01-09 23:59:54.079000+00:00   996680.69  33.34   996647.35      USD
# 2020-01-09 23:59:59.448000+00:00   996680.64  33.34   996647.30      USD
# 2020-01-09 23:59:59.448000+00:00   996680.64   0.00   996680.64      USD
#
#                                  account_id account_type base_currency  \
# 2020-01-01 17:00:10.447000+00:00    SIM-001       MARGIN           USD
# 2020-01-01 17:01:21.324000+00:00    SIM-001       MARGIN           USD
# 2020-01-01 17:01:21.324000+00:00    SIM-001       MARGIN           USD
# 2020-01-01 17:17:29.270000+00:00    SIM-001       MARGIN           USD
# 2020-01-01 17:17:29.270000+00:00    SIM-001       MARGIN           USD
# ...                                     ...          ...           ...
# 2020-01-09 23:59:42.322000+00:00    SIM-001       MARGIN           USD
# 2020-01-09 23:59:54.079000+00:00    SIM-001       MARGIN           USD
# 2020-01-09 23:59:54.079000+00:00    SIM-001       MARGIN           USD
# 2020-01-09 23:59:59.448000+00:00    SIM-001       MARGIN           USD
# 2020-01-09 23:59:59.448000+00:00    SIM-001       MARGIN           USD
#
#                                                                             margins  \
# 2020-01-01 17:00:10.447000+00:00                                              b'[]'
# 2020-01-01 17:01:21.324000+00:00                                              b'[]'
# 2020-01-01 17:01:21.324000+00:00  b'[{"type":"MarginBalance","initial":"0.00","m...
# 2020-01-01 17:17:29.270000+00:00  b'[{"type":"MarginBalance","initial":"0.00","m...
# 2020-01-01 17:17:29.270000+00:00                                              b'[]'
# ...                                                                             ...
# 2020-01-09 23:59:42.322000+00:00                                              b'[]'
# 2020-01-09 23:59:54.079000+00:00                                              b'[]'
# 2020-01-09 23:59:54.079000+00:00  b'[{"type":"MarginBalance","initial":"0.00","m...
# 2020-01-09 23:59:59.448000+00:00  b'[{"type":"MarginBalance","initial":"0.00","m...
# 2020-01-09 23:59:59.448000+00:00                                              b'[]'
#
#                                   reported   info
# 2020-01-01 17:00:10.447000+00:00      True  b'{}'
# 2020-01-01 17:01:21.324000+00:00     False  b'{}'
# 2020-01-01 17:01:21.324000+00:00     False  b'{}'
# 2020-01-01 17:17:29.270000+00:00     False  b'{}'
# 2020-01-01 17:17:29.270000+00:00     False  b'{}'
# ...                                    ...    ...
# 2020-01-09 23:59:42.322000+00:00     False  b'{}'
# 2020-01-09 23:59:54.079000+00:00     False  b'{}'
# 2020-01-09 23:59:54.079000+00:00     False  b'{}'
# 2020-01-09 23:59:59.448000+00:00     False  b'{}'
# 2020-01-09 23:59:59.448000+00:00     False  b'{}'
#
# [234213 rows x 10 columns]
